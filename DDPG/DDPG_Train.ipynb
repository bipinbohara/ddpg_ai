# %%
"""
Deep Deterministic Policy Gradient (DDPG), Reinforcement Learning.
P2P network, net bit rate, energy harvesting example for training.
Thanks to : https://github.com/MorvanZhou/Reinforcement-learning-with-tensorflow/tree/master/contents/9_Deep_Deterministic_Policy_Gradient_DDPG
Using:
tensorflow 1.0
"""
import math
#import tensorflow as tf

import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

import numpy as np
import gym
import time
import EH_P2P
import DDPG_CLASS
#from .DDPG_CLASS import * 

np.random.seed(1)
tf.set_random_seed(1)



#####################  hyper parameters  ####################

MAX_EPISODES = 2000
MAX_EP_STEPS = 120
LR_A = 0.0002   # learning rate for actor
LR_C = 0.0002  # learning rate for critic
GAMMA = 0.999    # reward discount
REPLACEMENT = [
    dict(name='soft', tau=0.01),
    dict(name='hard', rep_iter_a=600, rep_iter_c=500)
][0]            # you can try different target replacement strategies
MEMORY_CAPACITY = 40000
BATCH_SIZE = 80

OUTPUT_GRAPH = False
    
env=EH_P2P.EH_P2P()
env.Chanpower()
env.Solarread()
    
state_dim = 3 #channel,battery，solar
action_dim = 1 #Transmission power
action_bound = 1 #[0,1]

tip=1
tip2=1
snr=-10

for temp in range(1):
   #for snr in range(-10,10,2):
    for modulation in range(1):
        var = 10

        tf.reset_default_graph()
        sess = tf.Session()
        with tf.name_scope('S'):
            S = tf.placeholder(tf.float32, shape=[None, state_dim], name='s')
        with tf.name_scope('R'):
            R = tf.placeholder(tf.float32, [None, 1], name='r')
        with tf.name_scope('S_'):
            S_ = tf.placeholder(tf.float32, shape=[None, state_dim], name='s_')
        DDPG_CLASS.S=S
        DDPG_CLASS.R=R
        DDPG_CLASS.S_=S_
        actor = DDPG_CLASS.Actor(sess, action_dim, action_bound, LR_A, REPLACEMENT)
        critic = DDPG_CLASS.Critic(sess, state_dim, action_dim, LR_C, GAMMA, REPLACEMENT, actor.a, actor.a_)
        actor.add_grad_to_graph(critic.a_grads)
        M = DDPG_CLASS.Memory(MEMORY_CAPACITY, dims=2 * state_dim + action_dim + 1)


        sess.run(tf.global_variables_initializer())
        saver=tf.train.Saver(max_to_keep=100)

        if OUTPUT_GRAPH:
            tf.summary.FileWriter("logs/", sess.graph)

        print("modulation=",modulation,"snr=",snr)

        for i in range(MAX_EPISODES):
    
            s = env.reset_P2P(snr)

            ep_reward = 0
            for j in range(MAX_EP_STEPS):
                a = actor.choose_action(s)
                a = np.random.normal(a, var)
                a=np.clip(a,0,1)
                s_, r, info = env.step_P2P([a,modulation])#input modulation 0:qpsk,1:8psk,2:16qam

                M.store_transition(s, a, r , s_)

                if M.pointer > MEMORY_CAPACITY:
                    #tip and tip2 are only for printing`#
                    if tip == 1:
                        print("memory full",j,i)
                        tip=0
                    var *= 0.9995  # decay the action randomness
                    if tip2 == 1 and var<0.00000001:
                        print("var zero",j,i)
                        tip2=0
                        
                    b_M = M.sample(BATCH_SIZE)
                    b_s = b_M[:, :state_dim]
                    b_a = b_M[:, state_dim: state_dim + action_dim]
                    b_r = b_M[:, -state_dim - 1: -state_dim]
                    b_s_ = b_M[:, -state_dim:]

                    critic.learn(b_s, b_a, b_r, b_s_)
                    actor.learn(b_s)

                s = s_
                
                ep_reward += r


            if i % 30 == 0 :
                print("net bit rate=",r,"action",a, "solar,channel,battery",s,"epoch",i)
                print("ave_reward",ep_reward/(j+1))
                
                
                
        save_path = saver.save(sess, "folder_for_nn_noise"+"/EH_save_net_snr="+str(snr)+str(modulation)+"epoch="+str(i)+"_P2P.ckpt")
        print("Save to path: ", save_path)

print("----------------------------END--------------------------------")
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732827162.995423  166609 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# modulation= 0 snr= -10
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 0
# ave_reward 10928.9444897822
# net bit rate= 167221.96207069396 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 30
# ave_reward 8977.861273730221
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  0.649872 ] epoch 60
# ave_reward 13283.139889523778
# net bit rate= 10.267550861182801 action [0.94506751] solar,channel,battery [-0.031192   1.2813557  0.2096349] epoch 90
# ave_reward 5678.755011866165
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  0.487704 ] epoch 120
# ave_reward 9714.053783424228
# net bit rate= 77759.15947420071 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 150
# ave_reward 13406.187686943598
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 180
# ave_reward 9380.925585262527
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  0.487704 ] epoch 210
# ave_reward 13478.513543795612
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  0.649872 ] epoch 240
# ave_reward 13556.631073947327
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  0.487704 ] epoch 270
# ave_reward 11191.280819987924
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  0.649872 ] epoch 300
# ave_reward 14095.664325800135
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 330
# ave_reward 10949.163538203831
# memory full 40 333
# net bit rate= 36618.69893502926 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 360
# ave_reward 13654.249019161876
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 390
# ave_reward 5820.450875499473
# net bit rate= 302.43466458617553 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 420
# ave_reward 2192.210794936929
# net bit rate= 70.06975457754965 action [0.99962973] solar,channel,battery [-0.031192    1.2813557   0.19358096] epoch 450
# ave_reward 2211.1367778188987
# net bit rate= 71.69890854075186 action [0.99994838] solar,channel,battery [-0.031192   1.2813557  0.1934872] epoch 480
# ave_reward 2158.086831121273
# net bit rate= 70.76431321294064 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 510
# ave_reward 2153.956597817026
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 540
# ave_reward 2153.64517211458
# net bit rate= 70.59960708352 action [0.99999302] solar,channel,battery [-0.031192    1.2813557   0.19347405] epoch 570
# ave_reward 2153.748061023593
# net bit rate= 191813.48128970005 action [0.63268288] solar,channel,battery [-0.031192    1.2813557   0.60033643] epoch 600
# ave_reward 6014.630953511268
# net bit rate= 199697.74908849396 action [0.87060976] solar,channel,battery [-0.031192    1.2813557   0.33698326] epoch 630
# ave_reward 6205.983446118653
# net bit rate= 199676.99852226526 action [0.99241428] solar,channel,battery [-0.031192    1.2813557   0.20081218] epoch 660
# ave_reward 6889.659170882107
# var zero 76 678
# net bit rate= 199488.30463959463 action [0.99914778] solar,channel,battery [-0.031192    1.2813557   0.19425958] epoch 690
# ave_reward 6963.862584550553
# net bit rate= 199283.5046983628 action [0.99956518] solar,channel,battery [-0.031192    1.2813557   0.19386192] epoch 720
# ave_reward 6969.996522234565
# net bit rate= 198576.50367085938 action [0.99771494] solar,channel,battery [-0.031192   1.2813557  0.1953989] epoch 750
# ave_reward 7116.195641567583
# net bit rate= 190647.08283800745 action [0.88507754] solar,channel,battery [-0.031192    1.2813557   0.28306654] epoch 780
# ave_reward 7189.199950767581
# net bit rate= 199964.26560887933 action [0.99999946] solar,channel,battery [-0.031192    1.2813557   0.19347261] epoch 810
# ave_reward 8256.167783420595
# net bit rate= 199951.4448183694 action [0.99957496] solar,channel,battery [-0.031192   1.2813557  0.1939452] epoch 840
# ave_reward 9486.051868416394
# net bit rate= 199960.44316809048 action [0.99535632] solar,channel,battery [-0.031192    1.2813557   0.19874083] epoch 870
# ave_reward 8744.837199585098
# net bit rate= 0.0 action [0.00051075] solar,channel,battery [-0.031192   1.2813557  1.2875423] epoch 900
# ave_reward 8877.68873496037
# net bit rate= 0.0 action [7.42291326e-14] solar,channel,battery [-0.031192   1.2813557  1.2819319] epoch 930
# ave_reward 9023.077002509672
# net bit rate= 0.0 action [1.3421167e-11] solar,channel,battery [-0.031192   1.2813557  1.2790884] epoch 960
# ave_reward 9021.480331086126
# net bit rate= 0.0 action [6.94781527e-11] solar,channel,battery [-0.031192   1.2813557  1.2780133] epoch 990
# ave_reward 9020.36627085409
# net bit rate= 0.0 action [7.34455225e-17] solar,channel,battery [-0.031192   1.2813557  1.2781132] epoch 1020
# ave_reward 9026.59576944146
# net bit rate= 0.0 action [7.18669215e-19] solar,channel,battery [-0.031192   1.2813557  1.2768272] epoch 1050
# ave_reward 9024.308326334396
# net bit rate= 0.0 action [3.18409321e-19] solar,channel,battery [-0.031192   1.2813557  1.2750682] epoch 1080
# ave_reward 9018.649056789018
# net bit rate= 0.0 action [1.85160065e-20] solar,channel,battery [-0.031192   1.2813557  1.2747024] epoch 1110
# ave_reward 9017.963718107814
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  1.274654 ] epoch 1140
# ave_reward 9019.728722402371
# net bit rate= 0.0 action [1.02866433e-21] solar,channel,battery [-0.031192   1.2813557  1.2746302] epoch 1170
# ave_reward 9035.409555050885
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  1.274626 ] epoch 1200
# ave_reward 9113.633206207272
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  1.274624 ] epoch 1230
# ave_reward 9017.748649153882
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  1.274624 ] epoch 1260
# ave_reward 9018.002277316455
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  1.2894328] epoch 1290
# ave_reward 8321.765871344147
# net bit rate= 0.0 action [1.84966304e-26] solar,channel,battery [-0.031192   1.2813557  1.2994044] epoch 1320
# ave_reward 8458.361041046948
# net bit rate= 0.0 action [6.00311122e-26] solar,channel,battery [-0.031192   1.2813557  1.2874057] epoch 1350
# ave_reward 7981.995165393421
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  1.3002918] epoch 1380
# ave_reward 7910.846455921372
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  1.2746673] epoch 1410
# ave_reward 7753.895828931521
# net bit rate= 0.0 action [1.26228735e-28] solar,channel,battery [-0.031192   1.2813557  1.2752156] epoch 1440
# ave_reward 7732.38448670991
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  1.2748634] epoch 1470
# ave_reward 7904.075704825746
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  1.2749026] epoch 1500
# ave_reward 7948.873165872891
# net bit rate= 0.0 action [2.81496301e-31] solar,channel,battery [-0.031192   1.2813557  1.2746787] epoch 1530
# ave_reward 7712.698504527933
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  1.2748332] epoch 1560
# ave_reward 7714.896081357323
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  1.2749019] epoch 1590
# ave_reward 7721.177919521597
# net bit rate= 0.0 action [2.34211369e-33] solar,channel,battery [-0.031192   1.2813557  1.2851923] epoch 1620
# ave_reward 8911.454028490114
# net bit rate= 0.0 action [1.68071144e-34] solar,channel,battery [-0.031192   1.2813557  1.2817937] epoch 1650
# ave_reward 9786.018615548763
# net bit rate= 0.0 action [4.52136817e-35] solar,channel,battery [-0.031192   1.2813557  1.2759888] epoch 1680
# ave_reward 10112.040791125068
# net bit rate= 0.0 action [4.04857419e-36] solar,channel,battery [-0.031192   1.2813557  1.2778554] epoch 1710
# ave_reward 10375.388125987194
# net bit rate= 0.0 action [1.29145064e-36] solar,channel,battery [-0.031192   1.2813557  1.2757766] epoch 1740
# ave_reward 10152.708542270346
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  1.2746332] epoch 1770
# ave_reward 9657.743522280483
# net bit rate= 0.0 action [1.77105503e-38] solar,channel,battery [-0.031192   1.2813557  1.2746347] epoch 1800
# ave_reward 9901.536455443404
# net bit rate= 0.0 action [6.30737489e-39] solar,channel,battery [-0.031192   1.2813557  1.274929 ] epoch 1830
# ave_reward 9924.277986080215
# net bit rate= 0.0 action [3.81944664e-39] solar,channel,battery [-0.031192   1.2813557  1.2746254] epoch 1860
# ave_reward 9732.777342430565
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  1.2747386] epoch 1890
# ave_reward 10276.387313732008
# net bit rate= 0.0 action [1.90916278e-41] solar,channel,battery [-0.031192   1.2813557  1.2747706] epoch 1920
# ave_reward 9620.520410372123
# net bit rate= 0.0 action [3.4378364e-42] solar,channel,battery [-0.031192   1.2813557  1.2779658] epoch 1950
# ave_reward 10136.199417914397
# net bit rate= 0.0 action [1.40744446e-42] solar,channel,battery [-0.031192   1.2813557  1.2748616] epoch 1980
# ave_reward 10238.204677802021
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1999_P2P.ckpt
# ----------------------------END--------------------------------

# %%
"""
Deep Deterministic Policy Gradient (DDPG), Reinforcement Learning.
P2P network, net bit rate, energy harvesting example for training.
Thanks to : https://github.com/MorvanZhou/Reinforcement-learning-with-tensorflow/tree/master/contents/9_Deep_Deterministic_Policy_Gradient_DDPG
Using:
tensorflow 1.0
"""
import math
#import tensorflow as tf

import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

import numpy as np
import gym
import time
import EH_P2P
import DDPG_CLASS
#from .DDPG_CLASS import * 

np.random.seed(1)
tf.set_random_seed(1)



#####################  hyper parameters  ####################

MAX_EPISODES = 2000
MAX_EP_STEPS = 120
LR_A = 0.0002   # learning rate for actor
LR_C = 0.0002  # learning rate for critic
GAMMA = 0.999    # reward discount
REPLACEMENT = [
    dict(name='soft', tau=0.01),
    dict(name='hard', rep_iter_a=600, rep_iter_c=500)
][0]            # you can try different target replacement strategies
MEMORY_CAPACITY = 40000
BATCH_SIZE = 80

OUTPUT_GRAPH = False
    
env=EH_P2P.EH_P2P()
env.Chanpower()
env.Solarread()
    
state_dim = 3 #channel,battery，solar
action_dim = 1 #Transmission power
action_bound = 1 #[0,1]

tip=1
tip2=1
snr=-10

for temp in range(1):
   #for snr in range(-10,10,2):
    for modulation in range(1):
        var = 10

        tf.reset_default_graph()
        sess = tf.Session()
        with tf.name_scope('S'):
            S = tf.placeholder(tf.float32, shape=[None, state_dim], name='s')
        with tf.name_scope('R'):
            R = tf.placeholder(tf.float32, [None, 1], name='r')
        with tf.name_scope('S_'):
            S_ = tf.placeholder(tf.float32, shape=[None, state_dim], name='s_')
        DDPG_CLASS.S=S
        DDPG_CLASS.R=R
        DDPG_CLASS.S_=S_
        actor = DDPG_CLASS.Actor(sess, action_dim, action_bound, LR_A, REPLACEMENT)
        critic = DDPG_CLASS.Critic(sess, state_dim, action_dim, LR_C, GAMMA, REPLACEMENT, actor.a, actor.a_)
        actor.add_grad_to_graph(critic.a_grads)
        M = DDPG_CLASS.Memory(MEMORY_CAPACITY, dims=2 * state_dim + action_dim + 1)


        sess.run(tf.global_variables_initializer())
        saver=tf.train.Saver(max_to_keep=100)

        if OUTPUT_GRAPH:
            tf.summary.FileWriter("logs/", sess.graph)

        print("modulation=",modulation,"snr=",snr)

        for i in range(MAX_EPISODES):
    
            s = env.reset_P2P(snr)

            ep_reward = 0
            for j in range(MAX_EP_STEPS):
                a = actor.choose_action(s)
                a = np.random.normal(a, var)
                a=np.clip(a,0,1)
                s_, r, info = env.step_P2P([a,modulation])#input modulation 0:qpsk,1:8psk,2:16qam

                M.store_transition(s, a, r , s_)

                if M.pointer > MEMORY_CAPACITY:
                    #tip and tip2 are only for printing`#
                    if tip == 1:
                        print("memory full",j,i)
                        tip=0
                    var *= 0.9995  # decay the action randomness
                    if tip2 == 1 and var<0.00000001:
                        print("var zero",j,i)
                        tip2=0
                        
                    b_M = M.sample(BATCH_SIZE)
                    b_s = b_M[:, :state_dim]
                    b_a = b_M[:, state_dim: state_dim + action_dim]
                    b_r = b_M[:, -state_dim - 1: -state_dim]
                    b_s_ = b_M[:, -state_dim:]

                    critic.learn(b_s, b_a, b_r, b_s_)
                    actor.learn(b_s)

                s = s_
                
                ep_reward += r


            if i % 30 == 0 :
                print("net bit rate=",r,"action",a, "solar,channel,battery",s,"epoch",i)
                print("ave_reward",ep_reward/(j+1))
                
                
                
        save_path = saver.save(sess, "folder_for_nn_noise"+"/EH_save_net_snr="+str(snr)+str(modulation)+"epoch="+str(i)+"_P2P.ckpt")
        print("Save to path: ", save_path)

print("----------------------------END--------------------------------")
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1732832818.838532  231856 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# modulation= 0 snr= -10
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 0
# ave_reward 10824.538815802494
# net bit rate= 167221.96207069396 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 30
# ave_reward 9357.335596214483
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  0.649872 ] epoch 60
# ave_reward 13374.580659448722
# net bit rate= 10.268701378217846 action [0.94507037] solar,channel,battery [-0.031192    1.2813557   0.20963405] epoch 90
# ave_reward 6611.9438065377535
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  0.487704 ] epoch 120
# ave_reward 9876.8536318963
# net bit rate= 77759.15947420071 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 150
# ave_reward 13436.561659006182
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 180
# ave_reward 9397.505736147192
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  0.487704 ] epoch 210
# ave_reward 13570.180328723845
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  0.649872 ] epoch 240
# ave_reward 13558.729895584751
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  0.487704 ] epoch 270
# ave_reward 12484.657630399906
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  0.649872 ] epoch 300
# ave_reward 14204.522666349189
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 330
# ave_reward 10949.311247593345
# memory full 40 333
# net bit rate= 36627.122916626526 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 360
# ave_reward 11971.277839634953
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 390
# ave_reward 5818.389681019534
# net bit rate= 302.43567737964975 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 420
# ave_reward 2192.2108014169094
# net bit rate= 70.06975457754965 action [0.99962973] solar,channel,battery [-0.031192    1.2813557   0.19358096] epoch 450
# ave_reward 2211.136777896815
# net bit rate= 71.69890854075186 action [0.99994838] solar,channel,battery [-0.031192   1.2813557  0.1934872] epoch 480
# ave_reward 2158.0868311979634
# net bit rate= 70.76438605278516 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 510
# ave_reward 2153.9565984525816
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 540
# ave_reward 2153.64517211458
# net bit rate= 70.59960708352 action [0.99999302] solar,channel,battery [-0.031192    1.2813557   0.19347405] epoch 570
# ave_reward 2153.748061023593
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 600
# ave_reward 2153.743600482593
# net bit rate= 70.6144931866939 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 630
# ave_reward 2153.747255934834
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  2.4148674] epoch 660
# ave_reward 10072.29298002012
# var zero 76 678
# net bit rate= 0.0 action [3.63557474e-09] solar,channel,battery [-0.031192   1.2813557  0.6242268] epoch 690
# ave_reward 14121.406891706949
# net bit rate= 4.4619030858177894e-108 action [0.09691083] solar,channel,battery [-0.031192   1.2813557  0.7231063] epoch 720
# ave_reward 16724.41617380411
# net bit rate= 20794.2495158399 action [0.97735381] solar,channel,battery [-0.031192    1.2813557   0.20249006] epoch 750
# ave_reward 22802.575431784557
# net bit rate= 98889.07791635628 action [0.99929053] solar,channel,battery [-0.031192    1.2813557   0.19381218] epoch 780
# ave_reward 22763.694371374517
# net bit rate= 164164.00915210362 action [0.99968356] solar,channel,battery [-0.031192    1.2813557   0.19365507] epoch 810
# ave_reward 22655.26890857845
# net bit rate= 153660.6710497918 action [0.99998891] solar,channel,battery [-0.031192    1.2813557   0.19347817] epoch 840
# ave_reward 18753.535702530626
# net bit rate= 1514.1083991159182 action [0.72123557] solar,channel,battery [-0.031192   1.2813557  0.3213255] epoch 870
# ave_reward 17847.831827366153
# net bit rate= 167196.91409186585 action [0.99999988] solar,channel,battery [-0.031192    1.2813557   0.19347207] epoch 900
# ave_reward 18063.615732464183
# net bit rate= 167220.2622432522 action [0.99999988] solar,channel,battery [-0.031192    1.2813557   0.19347207] epoch 930
# ave_reward 18844.040377774592
# net bit rate= 1.5351663583360605e-237 action [0.0628669] solar,channel,battery [-0.031192    1.2813557   0.49475816] epoch 960
# ave_reward 15518.384322590486
# net bit rate= 77617.6549829308 action [0.99913543] solar,channel,battery [-0.031192   1.2813557  0.1938668] epoch 990
# ave_reward 17625.13367054291
# net bit rate= 167221.92838836167 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1020
# ave_reward 18038.539770428597
# net bit rate= 167222.26163385698 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1050
# ave_reward 18468.713117980697
# net bit rate= 168571.13794178743 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1080
# ave_reward 17191.234390743055
# net bit rate= 167221.9620536123 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1110
# ave_reward 17271.21171562447
# net bit rate= 167221.96148390157 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1140
# ave_reward 17291.400148521647
# net bit rate= 167221.96206634928 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1170
# ave_reward 16389.146471355278
# net bit rate= 167221.96206716623 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1200
# ave_reward 16976.176796723437
# net bit rate= 167221.96207069396 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1230
# ave_reward 17520.22286068518
# net bit rate= 167222.13498147568 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1260
# ave_reward 15836.425314964968
# net bit rate= 167221.96206434406 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1290
# ave_reward 16634.637178687808
# net bit rate= 167221.76618371508 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1320
# ave_reward 16431.53203826734
# net bit rate= 95.42724024139197 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1350
# ave_reward 14140.824209010992
# net bit rate= 161045.10841917794 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1380
# ave_reward 15936.207260136105
# net bit rate= 152627.54488816872 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1410
# ave_reward 16370.19547881308
# net bit rate= 165253.80011811835 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1440
# ave_reward 16472.11182345518
# net bit rate= 70.69049136198446 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1470
# ave_reward 17297.005214952744
# net bit rate= 12973.974000041408 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1500
# ave_reward 18130.230591007934
# net bit rate= 32056.995362870366 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1530
# ave_reward 18883.893638517984
# net bit rate= 75.81530251076767 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1560
# ave_reward 19507.23300420046
# net bit rate= 113.89539040742726 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1590
# ave_reward 19418.572974771152
# net bit rate= 70.61919618045481 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1620
# ave_reward 18720.095484895748
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1650
# ave_reward 17769.53441665021
# net bit rate= 70.6147184530367 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1680
# ave_reward 16972.74908352104
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1710
# ave_reward 17825.005596760016
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1740
# ave_reward 16490.74718951557
# net bit rate= 70.61551821958003 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1770
# ave_reward 18319.741529493327
# net bit rate= 73.13251555088829 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1800
# ave_reward 17082.30266453146
# net bit rate= 70.62228020202382 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1830
# ave_reward 19515.15163816248
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1860
# ave_reward 17511.92141959021
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1890
# ave_reward 17304.26204195707
# net bit rate= 72.95543679448231 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1920
# ave_reward 18333.44577781367
# net bit rate= 84.4673098808168 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1950
# ave_reward 17773.33213756379
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1980
# ave_reward 15135.775341710618
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1999_P2P.ckpt
# ----------------------------END--------------------------------

# %% [markdown]
# ## Critic Network Fix

# %%
"""
Deep Deterministic Policy Gradient (DDPG), Reinforcement Learning.
P2P network, net bit rate, energy harvesting example for training.
Thanks to : https://github.com/MorvanZhou/Reinforcement-learning-with-tensorflow/tree/master/contents/9_Deep_Deterministic_Policy_Gradient_DDPG
Using:
tensorflow 1.0
"""
import math
#import tensorflow as tf

import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

import numpy as np
import gym
import time
import EH_P2P
import DDPG_CLASS
#from .DDPG_CLASS import * 

np.random.seed(1)
tf.set_random_seed(1)



#####################  hyper parameters  ####################

MAX_EPISODES = 2000
MAX_EP_STEPS = 120
LR_A = 0.0002   # learning rate for actor
LR_C = 0.0002  # learning rate for critic
GAMMA = 0.999    # reward discount
REPLACEMENT = [
    dict(name='soft', tau=0.01),
    dict(name='hard', rep_iter_a=600, rep_iter_c=500)
][0]            # you can try different target replacement strategies
MEMORY_CAPACITY = 40000
BATCH_SIZE = 80

OUTPUT_GRAPH = False
    
env=EH_P2P.EH_P2P()
env.Chanpower()
env.Solarread()
    
state_dim = 3 #channel,battery，solar
action_dim = 1 #Transmission power
action_bound = 1 #[0,1]

tip=1
tip2=1
snr=-10

for temp in range(1):
   #for snr in range(-10,10,2):
    for modulation in range(1):
        var = 10

        tf.reset_default_graph()
        sess = tf.Session()
        with tf.name_scope('S'):
            S = tf.placeholder(tf.float32, shape=[None, state_dim], name='s')
        with tf.name_scope('R'):
            R = tf.placeholder(tf.float32, [None, 1], name='r')
        with tf.name_scope('S_'):
            S_ = tf.placeholder(tf.float32, shape=[None, state_dim], name='s_')
        DDPG_CLASS.S=S
        DDPG_CLASS.R=R
        DDPG_CLASS.S_=S_
        actor = DDPG_CLASS.Actor(sess, action_dim, action_bound, LR_A, REPLACEMENT)
        critic = DDPG_CLASS.Critic(sess, state_dim, action_dim, LR_C, GAMMA, REPLACEMENT, actor.a, actor.a_)
        actor.add_grad_to_graph(critic.a_grads)
        M = DDPG_CLASS.Memory(MEMORY_CAPACITY, dims=2 * state_dim + action_dim + 1)


        sess.run(tf.global_variables_initializer())
        saver=tf.train.Saver(max_to_keep=100)

        if OUTPUT_GRAPH:
            tf.summary.FileWriter("logs/", sess.graph)

        print("modulation=",modulation,"snr=",snr)

        for i in range(MAX_EPISODES):
    
            s = env.reset_P2P(snr)

            ep_reward = 0
            for j in range(MAX_EP_STEPS):
                a = actor.choose_action(s)
                a = np.random.normal(a, var)
                a=np.clip(a,0,1)
                s_, r, info = env.step_P2P([a,modulation])#input modulation 0:qpsk,1:8psk,2:16qam

                M.store_transition(s, a, r , s_)

                if M.pointer > MEMORY_CAPACITY:
                    #tip and tip2 are only for printing`#
                    if tip == 1:
                        print("memory full",j,i)
                        tip=0
                    var *= 0.9995  # decay the action randomness
                    if tip2 == 1 and var<0.00000001:
                        print("var zero",j,i)
                        tip2=0
                        
                    b_M = M.sample(BATCH_SIZE)
                    b_s = b_M[:, :state_dim]
                    b_a = b_M[:, state_dim: state_dim + action_dim]
                    b_r = b_M[:, -state_dim - 1: -state_dim]
                    b_s_ = b_M[:, -state_dim:]

                    critic.learn(b_s, b_a, b_r, b_s_)
                    actor.learn(b_s)

                s = s_
                
                ep_reward += r


            if i % 30 == 0 :
                print("net bit rate=",r,"action",a, "solar,channel,battery",s,"epoch",i)
                print("ave_reward",ep_reward/(j+1))
                
                
                
        save_path = saver.save(sess, "folder_for_nn_noise"+"/EH_save_net_snr="+str(snr)+str(modulation)+"epoch="+str(i)+"_P2P.ckpt")
        print("Save to path: ", save_path)

print("----------------------------END--------------------------------")
# Out:
# WARNING:tensorflow:From /opt/anaconda3/lib/python3.12/site-packages/tensorflow/python/compat/v2_compat.py:98: disable_resource_variables (from tensorflow.python.ops.resource_variables_toggle) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733081049.610709  889408 mlir_graph_optimization_pass.cc:401] MLIR V1 optimization pass is not enabled
# modulation= 0 snr= -10
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 0
# ave_reward 11473.990229628116
# net bit rate= 167221.96207069396 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 30
# ave_reward 9302.634592215882
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  0.649872 ] epoch 60
# ave_reward 13547.234521783179
# net bit rate= 10.269756120306216 action [0.945073] solar,channel,battery [-0.031192    1.2813557   0.20963328] epoch 90
# ave_reward 5678.144522169105
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  0.487704 ] epoch 120
# ave_reward 10448.401740572228
# net bit rate= 77759.15947420071 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 150
# ave_reward 14170.174765729493
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 180
# ave_reward 9508.193521455289
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  0.487704 ] epoch 210
# ave_reward 13561.758230754289
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  0.649872 ] epoch 240
# ave_reward 13559.787613184355
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  0.487704 ] epoch 270
# ave_reward 11270.404358383308
# net bit rate= 0.0 action [0.] solar,channel,battery [-0.031192   1.2813557  0.649872 ] epoch 300
# ave_reward 14092.47109465952
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 330
# ave_reward 10948.987631756925
# memory full 40 333
# net bit rate= 77759.15947420071 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 360
# ave_reward 15116.517212947745
# net bit rate= 0.5088000477739714 action [0.87833583] solar,channel,battery [-0.031192    1.2813557   0.22926949] epoch 390
# ave_reward 13351.01321566884
# net bit rate= 302.48125604565644 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 420
# ave_reward 11213.180859929014
# net bit rate= 70.07018771788006 action [0.99962973] solar,channel,battery [-0.031192    1.2813557   0.19358096] epoch 450
# ave_reward 8274.456022850856
# net bit rate= 71.69890854075186 action [0.99994838] solar,channel,battery [-0.031192   1.2813557  0.1934872] epoch 480
# ave_reward 10698.448970503476
# net bit rate= 70.76431321294064 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 510
# ave_reward 10952.47427949317
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 540
# ave_reward 16599.43272684944
# net bit rate= 70.59960708352 action [0.99999302] solar,channel,battery [-0.031192    1.2813557   0.19347405] epoch 570
# ave_reward 17005.796889649595
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 600
# ave_reward 18863.12116643677
# net bit rate= 70.6144931866939 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 630
# ave_reward 18580.145581908317
# net bit rate= 70.61431489746536 action [0.99999998] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 660
# ave_reward 15912.379902258657
# var zero 76 678
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 690
# ave_reward 16183.563732270008
# net bit rate= 70.61435653717292 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 720
# ave_reward 17209.4062091184
# net bit rate= 70.61435486896404 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 750
# ave_reward 18557.983638593767
# net bit rate= 70.61435479766864 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 780
# ave_reward 18084.048995516394
# net bit rate= 70.61435492930306 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 810
# ave_reward 17909.14593370214
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 840
# ave_reward 17366.04922456127
# net bit rate= 70.61435492511568 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 870
# ave_reward 15739.476385067252
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 900
# ave_reward 18271.77340211962
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 930
# ave_reward 18592.926922749386
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 960
# ave_reward 18548.68511761206
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 990
# ave_reward 13590.27294250661
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1020
# ave_reward 14628.4843122304
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1050
# ave_reward 14894.00673152629
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1080
# ave_reward 16153.399910458105
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1110
# ave_reward 16970.29684663404
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1140
# ave_reward 17003.506976786513
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1170
# ave_reward 17016.737801470998
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1200
# ave_reward 17010.46781217458
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1230
# ave_reward 17398.34424794513
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1260
# ave_reward 17007.832647326948
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1290
# ave_reward 17014.5550339009
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1320
# ave_reward 16964.618262998778
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1350
# ave_reward 15678.757493254683
# net bit rate= 70.61697180007602 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1380
# ave_reward 17068.44151792928
# net bit rate= 70.61435492552498 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1410
# ave_reward 15246.0180543878
# net bit rate= 70.85401578261143 action [0.99999982] solar,channel,battery [-0.031192    1.2813557   0.19347206] epoch 1440
# ave_reward 16563.582493269852
# net bit rate= 77759.15947420071 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1470
# ave_reward 18486.520702952268
# net bit rate= 77759.15947420071 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1500
# ave_reward 16718.83984622011
# net bit rate= 77759.15947420071 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1530
# ave_reward 18118.319405158098
# net bit rate= 77759.15947420071 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1560
# ave_reward 17755.99413268646
# net bit rate= 77759.15947420071 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1590
# ave_reward 17513.445944634397
# net bit rate= 77759.15947420071 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1620
# ave_reward 17230.753516919714
# net bit rate= 77759.15947420071 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1650
# ave_reward 17860.561004079584
# net bit rate= 167221.96207069396 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1680
# ave_reward 19244.89647924038
# net bit rate= 0.0 action [0.0001425] solar,channel,battery [-0.031192    1.2813557   0.65156627] epoch 1710
# ave_reward 17670.448326832535
# net bit rate= 167221.2827348249 action [0.99999696] solar,channel,battery [-0.031192    1.2813557   0.19347379] epoch 1740
# ave_reward 20152.674249168504
# net bit rate= 77461.33586267362 action [0.99931324] solar,channel,battery [-0.031192    1.2813557   0.19378544] epoch 1770
# ave_reward 18634.038364165986
# net bit rate= 196257.91055689793 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1800
# ave_reward 18916.398375783752
# net bit rate= 167221.96207069396 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1830
# ave_reward 20153.309742516645
# net bit rate= 167233.20752884162 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1860
# ave_reward 18994.350723498657
# net bit rate= 0.0 action [2.39575729e-05] solar,channel,battery [-0.031192    1.2813557   0.64986104] epoch 1890
# ave_reward 18719.09742984971
# net bit rate= 0.0 action [3.04813511e-05] solar,channel,battery [-0.031192   1.2813557  0.6498584] epoch 1920
# ave_reward 18107.384557223002
# net bit rate= 49.140382787682306 action [0.56310886] solar,channel,battery [-0.031192    1.2813557   0.41917267] epoch 1950
# ave_reward 17899.73931528026
# net bit rate= 199392.06066264474 action [1.] solar,channel,battery [-0.031192   1.2813557  0.193472 ] epoch 1980
# ave_reward 19341.187248436145
# Save to path:  folder_for_nn_noise/EH_save_net_snr=-100epoch=1999_P2P.ckpt
# ----------------------------END--------------------------------
